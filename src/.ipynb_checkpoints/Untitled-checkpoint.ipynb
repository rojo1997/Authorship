# %%
import time
import pandas as pd
import numpy as np
import string
import dill as pickle

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

from functions import real_xml, filter_df

from MLP.AuthorshipModel import AuthorshipModel

# %%
import os
os.chdir('C:/Users/ernes/Documents/Authorship')

# %%
random_state = 1
nwords = 1
frecuency = 1
subset = None
nfiles = None

# %%
df = real_xml('./iniciativas08/', nfiles = nfiles)
print(df.shape)
if subset != None: df = df.sample(10000, random_state = random_state)
print("Leido XML: ", df.shape)
print(time.strftime("%X"))

if nfiles == None: df = filter_df(df, nwords = nwords, frecuency = frecuency)
print("Filtro sobre Dataset: ", df.shape)

le = LabelEncoder()
le.fit(df['name'])
# Out:
# (58338, 2)
# Leido XML:  (58338, 2)
# 12:02:28
# antes:  (58338, 3)
# despues:  (58098, 3)
# despues:  (57989, 4)
# Filtro sobre Dataset:  (57989, 4)
# LabelEncoder()

# %%
A = df['nwords'].value_counts().head(5)
x = A.index.values
print(x)
y = A.values
fig, ax = plt.subplots()
ax.hit(x,y)
# Out:
# [17 13 12 18 19]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-345ac233a7be> in <module>
#       4 y = A.values
#       5 fig, ax = plt.subplots()
# ----> 6 ax.hit(x,y)
#
# AttributeError: 'AxesSubplot' object has no attribute 'hit'

# %%
print('Numero de documentos: ', df.shape[0])
print('Etiquetas: ', len(le.classes_))

X_train, X_test, y_train, y_test = train_test_split(
    df['text'],
    df['name'],
    test_size = 0.2,
    random_state = random_state
)
print("Train: ", X_train.shape)
print("Test: ", X_test.shape)
# Out:
# Numero de documentos:  58338
# Etiquetas:  596
# Train:  (46670,)
# Test:  (11668,)

# %%
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt

# %%
Vectorizer = CountVectorizer(
    #stop_words = self.stop_words,
    analyzer = 'word',
    encoding = 'utf8',
    dtype = np.float32,
    ngram_range = (1,1),
    #max_features = self.max_features,
    #min_df = 1.0 / 1000.0,
    #max_df = 999.0 / 1000.0,
    strip_accents = 'unicode',
    decode_error = 'replace',
    lowercase = True
)

# %%
Vectorizer.fit(X_train,y_train)
X = Vectorizer.transform(X_train)
Vectorizer.vocabulary_
# Out:
# {'se': 55864,
#  'or': 43688,
#  'as': 6046,
#  'por': 47012,
#  'favor': 27994,
#  'les': 37192,
#  'ruego': 55152,
#  'silencio': 56695,
#  'para': 44521,
#  'poder': 46787,
#  'continuar': 15021,
#  'la': 36656,
#  'intervenci': 35425,
#  'del': 17726,
#  'ponente': 46942,
#  'puede': 49618,
#  'usted': 62261,
#  'jim': 36273,
#  'nez': 42146,
#  'muchas': 41304,
#  'gracias': 30573,
#  'consejero': 14326,
#  'continuamos': 15019,
#  'con': 13398,
#  'el': 22843,
#  'orden': 43716,
#  'pasamos': 44860,
#  'siguiente': 56670,
#  'pregunta': 47710,
#  'de': 17163,
#  'respuesta': 53876,
#  'oral': 43696,
#  'relativa': 52586,
#  'lugares': 38191,
#  'inter': 35017,
#  'industrial': 33778,
#  'en': 23530,
#  'huelva': 31918,
#  'tiene': 60087,
#  'palabra': 44292,
#  'portavoz': 47084,
#  'parte': 44752,
#  'grupo': 30813,
#  'socialista': 57230,
#  'ora': 43689,
#  'mart': 39178,
#  'palanco': 44313,
#  'consejera': 14324,
#  'dirigida': 21281,
#  'consejer': 14323,
#  'hacienda': 31180,
#  'administraci': 1663,
#  'blica': 8647,
#  'al': 2776,
#  'plan': 46484,
#  'econ': 22521,
#  'micofinanciero': 40146,
#  'reequilibrio': 51757,
#  'junta': 36428,
#  'andaluc': 4125,
#  'formulada': 29007,
#  'nombre': 42379,
#  'parlamentario': 44720,
#  'popular': 46985,
#  'diputado': 21245,
#  'don': 22149,
#  'antonio': 4580,
#  'sanz': 55715,
#  'cabello': 9354,
#  'vaquero': 62609,
#  'pozo': 47357,
#  'me': 39465,
#  'he': 31298,
#  'quedado': 49826,
#  'estupefacta': 26385,
#  'frase': 29266,
#  'no': 42315,
#  'como': 12792,
#  'cristo': 16306,
#  'nos': 42466,
#  'ense': 24459,
#  'acab': 467,
#  'espero': 25804,
#  'que': 49808,
#  'lo': 37933,
#  'dijera': 21073,
#  'delegada': 17748,
#  'salud': 55510,
#  'hab': 31029,
#  'escuchado': 25483,
#  'si': 56551,
#  'juventud': 36532,
#  'hemos': 31354,
#  'un': 61995,
#  'poco': 46776,
#  'mesa': 39992,
#  'registrada': 52151,
#  'diga': 21007,
#  'game': 29777,
#  'presidente': 48043,
#  'cumplimos': 16932,
#  'acto': 1195,
#  'una': 61996,
#  'sesi': 56449,
#  'esta': 25903,
#  'comisi': 12781,
#  'votar': 63858,
#  'unas': 62005,
#  'enmiendas': 24322,
#  'presentadas': 47976,
#  'todos': 60337,
#  'los': 38084,
#  'grupos': 30814,
#  'pol': 46824,
#  'ticos': 60062,
#  'texto': 60007,
#  'definitiva': 17612,
#  'es': 25146,
#  'papel': 44492,
#  'mojado': 40759,
#  'estamos': 26005,
#  'ante': 4373,
#  'documento': 22062,
#  'presupuesto': 48192,
#  'consideramos': 14421,
#  'fallido': 27815,
#  'decimos': 17340,
#  'porque': 47053,
#  'recogiendo': 51138,
#  'definiciones': 17592,
#  'propio': 49095,
#  'vicepresidente': 63237,
#  'mico': 40138,
#  'sus': 58858,
#  'previsiones': 48305,
#  'cifras': 11667,
#  'est': 25902,
#  'absolutamente': 325,
#  'desactualizadas': 18409,
#  'este': 26078,
#  'ning': 42258,
#  'sentido': 56286,
#  'incapaz': 33085,
#  'antes': 4424,
#  'era': 25069,
#  'hace': 31149,
#  'cuesti': 16714,
#  'mes': 39991,
#  'ahora': 2644,
#  'menos': 39794,
#  'dada': 17064,
#  'realidad': 50608,
#  'mica': 40126,
#  'atraviesa': 6837,
#  'nuestra': 42692,
#  'comunidad': 13384,
#  'aut': 7081,
#  'noma': 42352,
#  'situaci': 56968,
#  'emergencia': 23218,
#  'social': 57221,
#  'luego': 38188,
#  'nosotros': 42468,
#  'pedimos': 45218,
#  'ser': 56356,
#  'estar': 26044,
#  'filosof': 28459,
#  'solbes': 57365,
#  'entendemos': 24499,
#  'gico': 30280,
#  'hubiese': 31896,
#  'sido': 56583,
#  'su': 57943,
#  'retirada': 54098,
#  'hasta': 31282,
#  'fecha': 28052,
#  'parece': 44654,
#  'irresponsable': 35954,
#  'gobierno': 30444,
#  'haya': 31284,
#  'corregido': 15777,
#  'escenarios': 25299,
#  'crecimiento': 16189,
#  'espa': 25632,
#  'meros': 39989,
#  'rojos': 54888,
#  'sigue': 56665,
#  'manteniendo': 38887,
#  'econom': 22522,
#  'ola': 43352,
#  'impensable': 32535,
#  'cuarto': 16598,
#  'trimestre': 61521,
#  'ejercicio': 22809,
#  'ya': 64035,
#  'las': 36871,
#  'puertas': 49630,
#  'recesi': 50944,
#  'dicen': 20783,
#  'expertos': 27076,
#  'pueda': 49615,
#  'traer': 60725,
#  'estas': 26049,
#  'digo': 21066,
#  'responsable': 53872,
#  'razonable': 50426,
#  'cambiado': 9792,
#  'escenario': 25298,
#  'tanto': 59257,
#  'hacia': 31179,
#  'baja': 7741,
#  'ha': 31028,
#  'hecho': 31306,
#  'seis': 56053,
#  'veces': 62705,
#  'yo': 64073,
#  'creo': 16223,
#  'imposible': 32746,
#  'mucho': 41305,
#  'pues': 49636,
#  'encontramos': 23848,
#  'escamotea': 25200,
#  'verdad': 62996,
#  'nunca': 42732,
#  'dec': 17245,
#  'amos': 3935,
#  'presentaci': 47973,
#  'volvemos': 63814,
#  'decir': 17344,
#  'cruenta': 16395,
#  'triste': 61572,
#  'teniendo': 59763,
#  'cuenta': 16688,
#  'mero': 39987,
#  'parados': 44540,
#  'arrojaba': 5890,
#  'inem': 33812,
#  'unos': 62131,
#  'superamos': 58583,
#  'setecientos': 56460,
#  'mil': 40251,
#  'escamoteaba': 25201,
#  'mucha': 41299,
#  'preocupaci': 47841,
#  'instalados': 34698,
#  'ficit': 28321,
#  'muy': 41566,
#  'preocupante': 47851,
#  'tica': 60037,
#  'tesorera': 59976,
#  'tambi': 59210,
#  'fondos': 28881,
#  'bancos': 7874,
#  'cuando': 16539,
#  'tenemos': 59738,
#  'necesidades': 41882,
#  'abordar': 216,
#  'facturas': 27714,
#  'hay': 31283,
#  'caj': 9504,
#  'inversi': 35700,
#  'real': 50596,
#  'cae': 9474,
#  'estos': 26217,
#  'presupuestos': 48193,
#  'plantea': 46562,
#  'bajada': 7744,
#  'impuestos': 32871,
#  'reducir': 51666,
#  'carga': 10321,
#  'fiscal': 28625,
#  'andaluces': 4126,
#  'pretende': 48204,
#  'austeridad': 7074,
#  'pantomima': 44481,
#  'pod': 46778,
#  'haber': 31036,
#  'bajar': 7753,
#  'cap': 10082,
#  'tulo': 61726,
#  'ii': 32306,
#  'iv': 36058,
#  'gasto': 29968,
#  'corriente': 15854,
#  'reducido': 51662,
#  'pero': 45817,
#  'eso': 25626,
#  'pone': 46935,
#  'evidencia': 26607,
#  'incapacidad': 33074,
#  'meter': 40044,
#  'tijera': 60107,
#  'din': 21182,
#  'incrementalista': 33448,
#  'situado': 56973,
#  'desde': 19132,
#  'tiempo': 60075,
#  'efectivamente': 22667,
#  'producen': 48644,
#  'recortes': 51399,
#  'sociales': 57225,
#  'dicho': 20789,
#  'todas': 60331,
#  'comparecencias': 12862,
#  'distintos': 21756,
#  'consejeros': 14327,
#  'aqu': 5354,
#  'cosa': 15972,
#  'fundamental': 29588,
#  'va': 62355,
#  'condicionar': 13758,
#  'nuestro': 42694,
#  'voto': 63878,
#  'negativo': 41959,
#  'antemano': 4386,
#  'atajan': 6545,
#  'problema': 48537,
#  'paro': 44726,
#  'primer': 48351,
#  'principal': 48381,
#  'tierra': 60097,
#  'alarmantes': 2869,
#  'somos': 57567,
#  'primera': 48352,
#  'mayor': 39416,
#  'tasa': 59370,
#  'toda': 60330,
#  'pr': 47375,
#  'cticamente': 16437,
#  'europa': 26499,
#  'indicadores': 33639,
#  'ah': 2614,
#  'siete': 56609,
#  'puntos': 49734,
#  'encima': 23793,
#  'media': 39502,
#  'nacional': 41587,
#  'crecimientos': 16190,
#  'pueden': 49619,
#  'situarnos': 56987,
#  'seg': 55975,
#  'analistas': 4047,
#  'financieros': 28558,
#  'internacionales': 35232,
#  'finales': 28482,
#  'precisamente': 47512,
#  'mantener': 38868,
#  'finalizar': 28504,
#  'importante': 32720,
#  'generan': 30078,
#  'confianza': 13909,
#  'durante': 22413,
#  'estado': 25974,
#  'mermando': 39979,
#  'reconoc': 51238,
#  'crisis': 16277,
#  'bamos': 7841,
#  'padeciendo': 44194,
#  'oles': 43371,
#  'cultiva': 16855,
#  'ocultando': 43110,
#  'ocultado': 43105,
#  'sembrando': 56125,
#  'enga': 24130,
#  'os': 43957,
#  'omite': 43468,
#  'cual': 16511,
#  'instrumentos': 34818,
#  'capacitados': 10093,
#  'afrontar': 2186,
#  'gran': 30627,
#  'mo': 40595,
#  'recupera': 51494,
#  'esa': 25147,
#  'perdida': 45560,
#  'absoluto': 327,
#  'desgobierno': 19479,
#  'reconociendo': 51260,
#  'haciendo': 31182,
#  'corrigen': 15860,
#  'retira': 54096,
#  'sumando': 58470,
#  'voluntades': 63798,
#  'podemos': 46785,
#  'tengamos': 59754,
#  'amparo': 3960,
#  'equipo': 25018,
#  'mismo': 40546,
#  'conocimiento': 14247,
#  'quiera': 49982,
#  'arrimemos': 5851,
#  'hombro': 31689,
#  'puesto': 49641,
#  'han': 31246,
#  'dado': 17067,
#  'ntoma': 42655,
#  'acogida': 860,
#  'nuestras': 42693,
#  'supuesto': 58805,
#  'actuando': 1239,
#  'consecuencia': 14296,
#  'buscando': 9280,
#  'consenso': 14336,
#  'atajando': 6546,
#  'cuanto': 16584,
#  'ingresos': 34164,
#  'gastos': 29970,
#  'volver': 63815,
#  'insistir': 34607,
#  'mantenemos': 38867,
#  'insuflados': 34831,
#  'justificar': 36506,
#  'desproporcionada': 20164,
#  'donde': 22167,
#  'inversiones': 35701,
#  'reales': 50603,
#  'caen': 9477,
#  'ticas': 60040,
#  'preocupan': 47849,
#  'bajan': 7750,
#  'son': 57568,
#  'bastante': 8081,
#  'calado': 9534,
#  'vienen': 63320,
#  'serie': 56375,
#  'promesas': 48894,
#  'zapatero': 64159,
#  'despu': 20186,
#  'llevan': 37874,
#  'caso': 10540,
#  'ley': 37273,
#  'dependencia': 18149,
#  'sufre': 58388,
#  'rdida': 50482,
#  'considerable': 14412,
#  'respecto': 53764,
#  'prometi': 48907,
#  'ayuntamientos': 7605,
#  'siguen': 56666,
#  'siendo': 56595,
#  'grandes': 30649,
#  'damnificados': 17092,
#  'olvidados': 43431,
#  'millones': 40308,
#  'deuda': 20607,
#  'van': 62574,
#  'pagar': 44243,
#  'nuevas': 42698,
#  'generaciones': 30034,
#  'intentar': 35003,
#  'paliar': 44344,
#  'raqu': 50302,
#  'cr': 16114,
#  'olvidan': 43433,
#  'nada': 41609,
#  'nuevo': 42701,
#  'indique': 33693,
#  'presupuestaria': 48183,
#  'llevando': 37875,
#  'peores': 45472,
#  'datos': 17150,
#  'ltimos': 38118,
#  'tiempos': 60077,
#  'sabemos': 55234,
#  'intertrimestral': 35415,
#  'creciendo': 16181,
#  'debajo': 17170,
#  'hac': 31148,
#  'ponemos': 46938,
#  'decreciendo': 17433,
#  'considerablemente': 14413,
#  'abandonamos': 32,
#  'relativamente': 52587,
#  'subdesarrollada': 58008,
#  'crece': 16168,
#  'ocurriendo': 43181,
#  'veinticinco': 62753,
#  'gesti': 30228,
#  'corregir': 15780,
#  'misma': 40542,
#  'incoherencia': 33278,
#  'programas': 48801,
#  'efecto': 22673,
#  'vaiv': 62424,
#  'modas': 40624,
#  'ponen': 46939,
#  'moda': 40613,
#  'otro': 44076,
#  'otras': 44074,
#  'coherencia': 12264,
#  'principio': 48387,
#  'pretenden': 48206,
#  'letra': 37219,
#  'peque': 45486,
#  'vez': 63171,
#  'llegar': 37814,
#  'esos': 25629,
#  'sitios': 56961,
#  'alar': 2818,
#  'trav': 61381,
#  'carencias': 10310,
#  'creemos': 16202,
#  'todav': 60332,
#  'existiendo': 26977,
#  'materia': 39288,
#  'educaci': 22626,
#  'sanidad': 55676,
#  'asuntos': 6494,
#  'innovaci': 34405,
#  'desarrollo': 18623,
#  'margen': 39074,
#  'maniobra': 38793,
#  'reglamento': 52199,
#  'permite': 45775,
#  'llamar': 37760,
#  'atenci': 6602,
#  'sobre': 57062,
#  'ciertos': 11647,
#  'casos': 10542,
#  'parecen': 44656,
#  'escandalosos': 25234,
#  'prometen': 48902,
#  'tras': 61148,
#  'cumplen': 16896,
#  'otros': 44078,
#  'siempre': 56592,
#  'olvido': 43451,
#  'humildad': 31983,
#  'oposici': 43624,
#  'pretendido': 48215,
#  'arreglar': 5753,
#  'desprop': 20162,
#  'sito': 56962,
#  'supone': 58744,
#  'desactualizado': 18410,
#  'palabras': 44293,
#  'servir': 56427,
#  'entre': 24641,
#  'cosas': 15973,
#  'ese': 25554,
#  'hizo': 31639,
#  'mintiendo': 40443,
#  'obviando': 43021,
#  'reconoce': 51239,
#  'abordarla': 219,
#  'carrillo': 10433,
#  'rez': 54533,
#  'much': 41298,
#  'simas': 56732,
#  'ampliaci': 3971,
#  'parque': 44734,
#  'ciencias': 11628,
#  'granada': 30628,
#  'formula': 29002,
#  'gallego': 29749,
#  'morales': 41016,
#  'brevedad': 9026,
#  'presidenta': 48041,
#  'hacer': 31160,
#  'algunas': 3231,
#  'reflexiones': 51899,
#  'lugar': 38189,
#  'quisiera': 50043,
#  'dejar': 17706,
#  'claro': 11923,
#  'escuchar': 25488,
#  'ambos': 3791,
#  'portavoces': 47083,
#  'agradecimiento': 2375,
#  'partido': 44825,
#  'aprobaci': 5178,
#  'representado': 53318,
#  'voluntad': 63797,
#  'nime': 42247,
#  'corporaci': 15728,
#  'municipal': 41472,
#  'propuesta': 49158,
#  'gicamente': 30278,
#  'encontrar': 23850,
#  'respaldo': 53755,
#  'decirle': 17348,
#  'jos': 36311,
#  'juan': 36329,
#  'az': 7609,
#  'trillo': 61514,
#  'all': 3364,
#  'fundamentos': 29602,
#  'razones': 50435,
#  'vale': 62441,
#  'temas': 59618,
#  'ciudadan': 11842,
#  'irresponsabilidades': 35953,
#  'responsabilidades': 53858,
#  'determinadas': 20555,
#  'administraciones': 1664,
#  'puedo': 49621,
#  'tal': 59165,
#  'compartir': 12908,
#  'entro': 24758,
#  'debate': 17177,
#  'tener': 59740,
#  'dejaciones': 17695,
#  'puedan': 49616,
#  'existir': 26984,
#  'quien': 49979,
#  'gobierna': 30440,
#  'hoy': 31884,
#  'ciudad': 11841,
#  'tengo': 59757,
#  'expresi': 27298,
#  'unanimidad': 62002,
#  'soberana': 57033,
#  'ciudadanos': 11848,
#  'ciudadanas': 11844,
#  'esto': 26195,
#  'dice': 20782,
#  'acuerdo': 1293,
#  'sustanciar': 58963,
#  'adecuadamente': 1418,
#  'justifica': 36488,
#  'realmente': 50648,
#  'marco': 39042,
#  'decretar': 17448,
#  'oficio': 43275,
#  'parlamento': 44724,
#  'actuaci': 1204,
#  'decretarlas': 17449,
#  'responsabilidad': 53857,
#  'dentro': 18088,
#  'soberan': 57032,
#  'provincial': 49367,
#  'termino': 59905,
#  'diciendo': 20798,
#  'aquello': 5367,
#  'decreto': 17454,
#  'mano': 38831,
#  'beneficio': 8316,
#  'conjunto': 14160,
#  'barriada': 8005,
#  'cubillas': 16636,
#  'dos': 22197,
#  'telares': 59523,
#  'llegan': 37812,
#  'cierto': 11646,
#  'rifirrafe': 54627,
#  'car': 10194,
#  'cter': 16433,
#  'exclusivamente': 26829,
#  'tico': 60044,
#  'mara': 38967,
#  'voy': 63881,
#  'anunciar': 4641,
#  'proposiciones': 49151,
#  'vamos': 62569,
#  'afirmativamente': 2118,
#  'incorporarme': 33415,
#  'mi': 40123,
#  'afirmativo': 2120,
#  'resto': 53942,
#  'debatir': 17192,
#  'querido': 49943,
#  'director': 21265,
#  'general': 30043,
#  'ayuntamiento': 7600,
#  'laga': 36720,
#  'protagonizado': 49253,
#  'ltimas': 38116,
#  'semanas': 56115,
#  'esc': 25160,
#  'ndalos': 41794,
#  'eco': 22498,
#  'medios': 39602,
#  'comunicaci': 13357,
#  'delegado': 17750,
#  'urbanismo': 62150,
#  'adjudic': 1615,
#  'piscina': 46400,
#  'forma': 28934,
#  'irregular': 35930,
#  'amigo': 3850,
#  'pag': 44219,
#  'cinco': 11701,
#  'licencia': 37399,
#  'obras': 42871,
#  'domicilio': 22121,
#  'sabe': 55231,
#  'reparte': 53088,
#  'reparti': 53090,
#  'manera': 38728,
#  'contratos': 15224,
#  'empresas': 23498,
#  'afines': 2091,
#  'muchos': 41306,
#  'fue': 29446,
#  'concejala': 13447,
#  'teresa': 59846,
#  'porras': 47058,
#  'opacidad': 43524,
#  'salt': 55482,
#  'ndose': 41846,
#  'controles': 15301,
#  'blicos': 8658,
#  'concesi': 13508,
#  'qu': 49799,
#  'perder': 45546,
#  'legalidad': 37049,
#  'expediente': 27036,
#  'llega': 37804,
#  'elecciones': 22880,
#  'municipales': 41473,
#  'quer': 49915,
#  'saber': 55237,
#  'tipo': 60185,
#  'cobertura': 12096,
#  'le': 36974,
#  'canal': 9926,
#  'sur': 58813,
#  'televisi': 59597,
#  'asunto': 6493,
#  'fechas': 28057,
#  'diputada': 21243,
#  'terminar': 59885,
#  'agradecerle': 2365,
#  'trabajo': 60669,
#  'desempe': 19249,
#  'ado': 1739,
#  'per': 45489,
#  'odo': 43200,
#  'sesiones': 56450,
#  'sin': 56811,
#  'perjuicio': 45727,
#  'leg': 37040,
#  'timo': 60143,
#  'derecho': 18248,
#  'corresponde': 15807,
#  'rganos': 54554,
#  'calendario': 9604,
#  'sea': 55865,
#  'ltima': 38114,
#  'quiero': 49988,
#  'agradecerles': 2366,
#  'fuerzas': 29484,
#  'comprensi': 13223,
#  'tono': 60423,
#  'incluso': 33247,
#  'aspectos': 6410,
#  'controversia': 15303,
#  'dificultad': 20954,
#  'desearles': 19187,
#  'realicen': 50607,
#  'buen': 9155,
#  'ximo': 64011,
#  'disfruten': 21516,
#  'merecido': 39938,
#  'descanso': 18814,
#  'verles': 63059,
#  'septiembre': 56342,
#  'volveremos': 63816,
#  'empezar': 23381,
#  'curso': 17022,
#  'extensi': 27395,
#  'siento': 56602,
#  'concluido': 13585,
#  'pleno': 46692,
#  'aval': 7358,
#  'isnasa': 36012,
#  'jorge': 36299,
#  'luis': 38195,
#  'ramos': 50268,
#  'aznar': 7626,
#  'repito': 53216,
#  'manifiesto': 38786,
#  'subido': 58034,
#  'interesa': 35108,
#  'cu': 16458,
#  'dici': 20794,
#  'ndole': 41839,
#  'hablando': 31124,
#  'ustedes': 62262,
#  'apoyaron': 5074,
#  'gobernaron': 30434,
#  'fueron': 29477,
#  'capaces': 10084,
#  'sacar': 55281,
#  'dejaron': 17718,
#  'persona': 45914,
#  'sacarla': 55285,
#  'presentara': 47988,
#  'movimiento': 41261,
#  'demuestra': 17988,
#  'andando': 4151,
#  'pez': 46129,
#  'causa': 10714,
#  'cierta': 11643,
#  'perplejidad': 45847,
#  'criticando': 16326,
#  'cheque': 11403,
#  'beb': 8169,
#  'medidas': 39565,
#  'votaron': 63869,
#  'contra': 15047,
#  'momento': 40825,
#  'tendr': 59729,
#  'an': 4021,
#  'poquito': 47010,
#  'coherentes': 12268,
#  'pedirle': 45223,
#  'peras': 45494,
#  'olmo': 43412,
#  'aplausos': 4919,
#  'zar': 64172,
#  'simo': 56749,
#  'aportaci': 5001,
#  'especial': 25672,
#  'pedido': 45210,
#  'comparecencia': 12861,
#  'federaci': 28072,
#  'representa': 53311,
#  'agradecer': 2363,
#  'solo': 57459,
#  'hombres': 31688,
#  'mujeres': 41356,
#  'tienen': 60088,
#  'discapacidad': 21312,
#  'sino': 56877,
#  'reclamaci': 51066,
#  'bueno': 9163,
#  'mitad': 40559,
#  'poblaci': 46753,
#  'sufrido': 58394,
#  'hist': 31619,
#  'ricamente': 54578,
#  'discriminaci': 21378,
#  've': 62699,
#  'traslado': 61233,
#  'queremos': 49931,
#  'garantizar': 29880,
#  'proyecto': 49450,
#  'dejado': 17701,
#  'ver': 62952,
#  'ni': 42192,
#  'concepto': 13476,
#  'paradigma': 44533,
#  'recuperaci': 51497,
#  'enfermedad': 24063,
#  'sica': 56559,
#  'mental': 39835,
#  'acu': 1253,
#  'ando': 4166,
#  'igual': 32277,
#  'bienestar': 8465,
#  'calidad': 9637,
#  'vida': 63276,
#  'permita': 45771,
#  'plenitud': 46691,
#  'individual': 33721,
#  'reclaman': 51073,
#  'discriminaciones': 21379,
#  'impedimentos': 32525,
#  'igualdad': 32292,
#  'oportunidades': 43617,
#  'mbitos': 39448,
#  'todo': 60333,
#  'vean': 62702,
#  'contemplados': 14881,
#  'alusi': 3656,
#  'ello': 23032,
#  'fin': 28479,
#  'comparto': 12914,
#  'debe': 17200,
#  'personas': 45950,
#  'conformamos': 14007,
#  'aportamos': 5009,
#  'esfuerzo': 25586,
#  'diario': 20755,
#  'pro': 48502,
#  'colectivo': 12401,
#  'trae': 60722,
#  'proposici': 49150,
#  'apoyar': 5063,
#  'favorablemente': 27997,
#  'rminos': 54758,
#  'concretos': 13655,
#  'estatuto': 26073,
#  'contempla': 14873,
#  'ninguna': 42260,
#  'cl': 11867,
#  'usula': 62272,
#  'garant': 29859,
#  'presupuestadas': 48176,
#  'generales': 30044,
#  'ejecutadas': 22740,
#  'existen': 26968,
#  'partidas': 44817,
#  'anteriores': 4421,
#  'frustraci': 29414,
#  'expectativas': 27027,
#  'timas': 60136,
#  'creadas': 16133,
#  'funci': 29522,
#  'ir': 35873,
#  'cumpliendo': 16908,
#  'presupuestario': 48186,
#  'acci': 586,
#  'defraudan': 17648,
#  'paso': 44925,
#  'necesita': 41884,
#  'posiblemente': 47172,
#  'comunidades': 13385,
#  'nomas': 42357,
#  'nivel': 42290,
#  'homologable': 31723,
#  'regiones': 52143,
#  'uni': 62015,
#  'europea': 26505,
#  'entorno': 24597,
#  'contexto': 14975,
#  'debemos': 17201,
#  'compararnos': 12846,
#  'referirnos': 51823,
#  'cualquier': 16535,
#  'necesidad': 41881,
#  'perentoria': 45612,
#  'financiaci': 28521,
#  'falta': 27846,
#  'hora': 31786,
#  'medir': 39604,
#  'convergencia': 15405,
#  'nuestros': 42695,
#  'referentes': 51810,
#  'fuera': 29469,
#  'situar': 56977,
#  'primase': 48341,
#  'contemplaci': 14876,
#  'ad': 1355,
#  'nde': 41810,
#  'gastar': 29955,
#  'dan': 17095,
#  'recaudar': 50894,
#  'poca': 46773,
#  'vacas': 62366,
#  'flacas': 28681,
#  'poniendo': 46963,
#  'acento': 651,
#  'fuentes': 29463,
#  'habla': 31113,
#  'agravios': 2423,
#  'comparativos': 12854,
#  'agravio': 2422,
#  'comparativo': 12853,
#  'entenderlo': 24505,
#  'abusamos': 452,
#  'comparaciones': 12830,
#  'odiosas': 43197,
#  'pasa': 44844,
#  'fuerza': 29482,
#  'incrementar': 33452,
#  'capacidad': 10085,
#  'gusta': 30997,
#  'hable': 31141,
#  'rica': 54577,
#  'nueva': 42696,
#  'vieja': 63311,
#  'bien': 8461,
#  'rmino': 54757,
#  'suficientemente': 58367,
#  'polemizado': 46838,
#  'largo': 36857,
#  'coet': 12196,
#  'nea': 41861,
#  'historia': 31623,
#  'mide': 40206,
#  'ntos': 42659,
#  'reivindicaci': 52485,
#  'actual': 1208,
#  'futuro': 29676,
#  'estoy': 26218,
#  'convencido': 15354,
#  'listos': 37690,
#  'redactar': 51568,
#  'autonom': 7254,
#  'eh': 22720,
#  'timamente': 60134,
#  'reivindiquemos': 52506,
#  'trato': 61370,
#  'sencillamente': 56199,
#  'adem': 1484,
#  'falsear': 27831,
#  'disposici': 21677,
#  'adicional': 1549,
#  'tercera': 59825,
#  'viene': 63319,
#  'cobrar': 12117,
#  'peso': 46080,
#  'poblacional': 46754,
#  'final': 28481,
#  'usulas': 62273,
#  'lado': 36706,
#  'contemplan': 14883,
#  'cumplimentar': 16922,
#  ...}

# %%
suma = X.sum(axis = 0)
words_freq = [(word, suma[0,idx]) for word, idx in Vectorizer.vocabulary_.items()]
words_freq = sorted(words_freq, key = lambda x: x[1], reverse = True)
words_freq[:10]
# Out:
# [('de', 700842.0),
#  ('que', 518938.0),
#  ('la', 389484.0),
#  ('en', 321489.0),
#  ('el', 272735.0),
#  ('se', 223706.0),
#  ('los', 158813.0),
#  ('no', 141399.0),
#  ('es', 128702.0),
#  ('del', 116744.0)]

# %%
ws = []
fs = []
for w,f in words_freq[:25]:
    ws.append(w)
    fs.append(f)
fs
# Out:
# [700842.0,
#  518938.0,
#  389484.0,
#  321489.0,
#  272735.0,
#  223706.0,
#  158813.0,
#  141399.0,
#  128702.0,
#  116744.0,
#  113053.0,
#  111014.0,
#  108103.0,
#  99363.0,
#  92808.0,
#  85532.0,
#  83517.0,
#  63112.0,
#  62683.0,
#  55195.0,
#  52601.0,
#  48534.0,
#  47167.0,
#  45454.0,
#  42135.0]

# %%
fig, ax = plt.subplots()
hist = ax.bar(ws,fs)
plt.xticks(ws,ws, rotation = 'vertical')
plt.xlabel('Tokens')
plt.ylabel('Frecuencia absoluta')
plt.title('Distribución de frecuencias de la plabras')
ax.plot()
# Out:
# []
